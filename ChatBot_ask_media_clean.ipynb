# %%
import pandas as pd 
import numpy as np
import openai

# %%
api_key = open('API_key.txt', 'r').readline().strip()
openai.api_key = api_key

# %% [markdown]
# # User inputs

# %%
# question to ask media
request = "Чем занимается Путин"
dates = ['2022-08-01', '2022-12-31'] # list of min and max dates. If only one date - assumed to be min date.
sources = [] # list of sources. Must be exact match to the source name in the dataset 
stance = ['moder'] # list of stances. Must be exact match to the content type in the dataset ['inet propaganda', 'altern', 'tv', 'moder', 'voenkor']

model_name = "gpt-3.5-turbo" # model for summarization
# better model can accomodate more news
# however, the effect of more news in context should be tested
if model_name == "gpt-3.5-turbo": #4K (~10 news)
    price_1K = 0.0015 # price per 1000 characters
elif model_name == "gpt-3.5-turbo-16k": #16K (~40 news)
    price_1K = 0.003
elif model_name == "gpt-4": #8K (~20 news)
    price_1K = 0.03
elif model_name == "gpt-4-32k": #32K (~80 news)
    price_1K = 0.06

# %% [markdown]
# ### load pickle df & filter

# %%
def get_filtered_df(request, dates=None, sources=None, stance=None):
    # load dataset
    df_filtered = pd.read_pickle('../TG news channels/filtered/df_war_ukr_filtered_ada_emb.pkl')
    full_len = df_filtered.shape[0]
    # filter by date, source, stance
    if dates:
        if len(dates) == 1:
            df_filtered = df_filtered[df_filtered['date'] >= dates[0]]
        elif len(dates) == 2:
            df_filtered = df_filtered[(df_filtered['date'] >= dates[0]) & (df_filtered['date'] <= dates[1])]
    if sources:
        df_filtered = df_filtered[df_filtered['source'].isin(sources)]
    if stance:
        df_filtered = df_filtered[df_filtered['stance'].isin(stance)]

    print(f"Number of messages in the filtered dataset: {df_filtered.shape[0]}, {df_filtered.shape[0]/full_len*100:.2f}% of the full dataset")

    return df_filtered

# %% [markdown]
# ## find top relevant news

# %%
# embed request
def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']

# %%
# OPTION 1: find top N news closest to request (cosine similarity)

# optional parameter request_emb
def get_top_openai(df, request=None, request_emb=None, model="text-embedding-ada-002", top_n=10):
    if request_emb is None and request is None:
        print('Error: no request')
        return
    if request_emb is None:
        request_emb = get_embedding(request)
    df['cos_sim'] = df['emb'].apply(lambda x: np.dot(x, request_emb)/(np.linalg.norm(x)*np.linalg.norm(request_emb)))
    top_sim_news = df.sort_values(by='cos_sim', ascending=False).head(top_n)
    news4request = '\n'.join(top_sim_news.cleaned_message.tolist())
    return news4request

# %% [markdown]
# ## Ask OpenAI

# %%
# simple function - suceptible to openai disconnection

def ask_openai(request, news4request, model_name = "gpt-3.5-turbo"):
    response = openai.ChatCompletion.create(
        model = model_name,
        messages=[
            {
            "role": "system",
            "content": "You are given few short texts in Russian. Based on this texts answer the following question:\n{request}. \nОтвечай на русском."
            },
            {
            "role": "user",
            "content": news4request
            }
        ],
        temperature=1,
        max_tokens=512,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
        )
    return response

# %%
df_filtered = get_filtered_df(request, dates=dates, sources=sources, stance=stance)
news4request = get_top_openai(df_filtered, request=request, model="text-embedding-ada-002", top_n=10)

reply = ask_openai(request, news4request, model_name = model_name)
# Out:
# Number of messages in the filtered dataset: 3518, 3.17% of the full dataset

# %%
df_ = df_filtered[:10]
# "https://t.me/"+str(channel_name)+"/"+str(msg_id)
# link = "https://t.me/"+str(df_.channel_name)+"/"+str(df_.msg_id)
df_['link'] = df_.apply(lambda x: "https://t.me/"+str(x.channel_name)+"/"+str(x.msg_id), axis=1)
# Out:
# /var/folders/2f/4wrcxd5n7_zbgfnwpf77l3bm0000gn/T/ipykernel_37595/469845138.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['link'] = df_.apply(lambda x: "https://t.me/"+str(x.channel_name)+"/"+str(x.msg_id), axis=1)

# %%
df_
# Out:
#        channel_id channel_name  msg_id  \
# 19920  1038402501   kommersant   45459
# 19921  1038402501   kommersant   45419
# 19922  1038402501   kommersant   45407
# 19923  1038402501   kommersant   45402
# 19924  1038402501   kommersant   45384
# 19925  1038402501   kommersant   45376
# 19926  1038402501   kommersant   45365
# 19927  1038402501   kommersant   45359
# 19928  1038402501   kommersant   45296
# 19929  1038402501   kommersant   45295
#
#                                                  message  \
# 19920  Гости, подарки и нарядная елка не помогают отв...
# 19921  Главные заявления пресс-секретаря президента Р...
# 19922  Кадры задержания прибывшего в Россию мужчины, ...
# 19923  🇧🇾Минобороны Белоруссии не исключает, что паде...
# 19924  ◾️Президент РФ Владимир Путин освободил участн...
# 19925  🇧🇾🇺🇦Посла Украины вызвали в МИД Белоруссии пос...
# 19926  ❗️На территории Белоруссии упала украинская ра...
# 19927  Глава Главного управления разведки Министерств...
# 19928  Кадры с места ликвидации двух боевиков, которы...
# 19929  Двух боевиков, готовивших теракт в Чегеме по з...
#
#                                          cleaned_message        date  views  \
# 19920  Гости, подарки и нарядная елка не помогают отв...  2022-12-31  36982
# 19921  Главные заявления пресс-секретаря президента Р...  2022-12-30  32615
# 19922  Кадры задержания прибывшего в Россию мужчины, ...  2022-12-30  33275
# 19923  Минобороны Белоруссии не исключает, что падени...  2022-12-30  41943
# 19924  ◾Президент РФ Владимир Путин освободил участни...  2022-12-29  35776
# 19925  Посла Украины вызвали в МИД Белоруссии после п...  2022-12-29  48051
# 19926  ❗На территории Белоруссии упала украинская рак...  2022-12-29  36831
# 19927  Глава Главного управления разведки Министерств...  2022-12-29  41200
# 19928  Кадры с места ликвидации двух боевиков, которы...  2022-12-28  37309
# 19929  Двух боевиков, готовивших теракт в Чегеме по з...  2022-12-28  50184
#
#        number_replies  number_forwards  contains_media            media_type  \
# 19920              37              100           False                   NaN
# 19921              45               37            True     MessageMediaPhoto
# 19922              43               15            True  MessageMediaDocument
# 19923              29               24           False                   NaN
# 19924              58               10            True     MessageMediaPhoto
# 19925              45               43           False                   NaN
# 19926              72              152           False                   NaN
# 19927              52               65           False                   NaN
# 19928               8               24            True  MessageMediaDocument
# 19929              24               29           False                   NaN
#
#        has_url  url domain document_type  \
# 19920    False  NaN    NaN           NaN
# 19921    False  NaN    NaN           NaN
# 19922    False  NaN    NaN     video/mp4
# 19923    False  NaN    NaN           NaN
# 19924    False  NaN    NaN           NaN
# 19925    False  NaN    NaN           NaN
# 19926    False  NaN    NaN           NaN
# 19927    False  NaN    NaN           NaN
# 19928    False  NaN    NaN     video/mp4
# 19929    False  NaN    NaN           NaN
#
#                                                      emb stance   cos_sim  \
# 19920  [-0.022998705506324768, -0.010879949666559696,...  moder  0.808453
# 19921  [-0.017266251146793365, -0.002344595966860652,...  moder  0.845058
# 19922  [-0.008091169409453869, -0.024526357650756836,...  moder  0.816336
# 19923  [-0.024069178849458694, -0.009593642316758633,...  moder  0.806556
# 19924  [-0.00641512218862772, -0.009843776933848858, ...  moder  0.834342
# 19925  [-0.011971070431172848, -0.006854776293039322,...  moder  0.791700
# 19926  [-0.012420917861163616, -0.0008996535325422883...  moder  0.775438
# 19927  [-0.012306863442063332, -0.007884803228080273,...  moder  0.812769
# 19928  [-0.024571457877755165, -0.0015501478919759393...  moder  0.791579
# 19929  [-0.020512806251645088, -0.008688247762620449,...  moder  0.800489
#
#                                 link
# 19920  https://t.me/kommersant/45459
# 19921  https://t.me/kommersant/45419
# 19922  https://t.me/kommersant/45407
# 19923  https://t.me/kommersant/45402
# 19924  https://t.me/kommersant/45384
# 19925  https://t.me/kommersant/45376
# 19926  https://t.me/kommersant/45365
# 19927  https://t.me/kommersant/45359
# 19928  https://t.me/kommersant/45296
# 19929  https://t.me/kommersant/45295

# %%
reply_text = reply.choices[0]['message']['content']
n_tokens_used = reply.usage.total_tokens
reply_cost = n_tokens_used / 1000 * price_1K
print(f"Cost - ${round(reply_cost, 3)}")
print(f"Request: {request}; \nFilters: dates: {dates}; sources: {sources}; stance: {stance}")
print()
# print wrapped text
print(reply_text)
# Out:
# Cost - $0.003
# Request: Чем занимается Путин;
# Filters: dates: ['2022-08-01', '2022-12-31']; sources: []; stance: ['moder']
#
# Based on the given texts, it can be inferred that Vladimir Putin is involved in various activities related to international relations, domestic agriculture, and discussions on the situation in Ukraine. He has been in contact with leaders from China, France, Germany, and also communicated with Dmitry Medvedev. Putin's statements suggest that he is concerned about the Ukrainian crisis and emphasizes the need for a balanced approach. He also discusses issues related to the Zaporizhzhia Nuclear Power Plant and the Ukrainian grain exports. Furthermore, Putin expresses his views on the actions of Western countries and highlights the importance of investigating terrorist attacks on Russian infrastructure. Overall, Putin appears to be actively engaged in diplomatic discussions and decision-making processes, particularly regarding Ukraine and Russia's relationships with other countries.

# %%
# add reply & inputs to csv-file
import csv

# if file does not exist write header
if not os.path.isfile('openai_chatbot.csv'):
    with open('openai_chatbot.csv', 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['request', 'dates', 'sources', 'stance', 'reply_text', 'reply_cost'])

with open('openai_chatbot.csv', 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow([request, dates, sources, stance, reply_text, reply_cost])

# %% [markdown]
# # TG bot

# %%
from telegram import Update
from telegram.ext import ApplicationBuilder, CommandHandler, ContextTypes


async def hello(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    await update.message.reply_text(f'Hello {update.effective_user.first_name}')


tg_token = open('tg_api.txt', 'r').readline().strip()

app = ApplicationBuilder().token(tg_token).build()

app.add_handler(CommandHandler("hello", hello))

app.run_polling()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/ask_media/lib/python3.10/site-packages/telegram/ext/_application.py:957, in Application.__run(self, updater_coroutine, stop_signals, close_loop)
#     956     updater_coroutine.close()
# --> 957     raise exc
#     958 finally:
#     959     # We arrive here either by catching the exceptions above or if the loop gets stopped
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/site-packages/telegram/ext/_application.py:946, in Application.__run(self, updater_coroutine, stop_signals, close_loop)
#     945 try:
# --> 946     loop.run_until_complete(self.initialize())
#     947     if self.post_init:
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/asyncio/base_events.py:625, in BaseEventLoop.run_until_complete(self, future)
#     624 self._check_closed()
# --> 625 self._check_running()
#     627 new_task = not futures.isfuture(future)
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/asyncio/base_events.py:584, in BaseEventLoop._check_running(self)
#     583 if self.is_running():
# --> 584     raise RuntimeError('This event loop is already running')
#     585 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/ask_media/lib/python3.10/site-packages/telegram/ext/_application.py:968, in Application.__run(self, updater_coroutine, stop_signals, close_loop)
#     967     loop.run_until_complete(self.post_stop(self))
# --> 968 loop.run_until_complete(self.shutdown())
#     969 if self.post_shutdown:
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/asyncio/base_events.py:625, in BaseEventLoop.run_until_complete(self, future)
#     624 self._check_closed()
# --> 625 self._check_running()
#     627 new_task = not futures.isfuture(future)
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/asyncio/base_events.py:584, in BaseEventLoop._check_running(self)
#     583 if self.is_running():
# --> 584     raise RuntimeError('This event loop is already running')
#     585 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin@gmail.com/My Drive/Colab Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb Cell 16 line 1
#      <a href='vscode-notebook-cell:/Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin%40gmail.com/My%20Drive/Colab%20Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb#Y122sZmlsZQ%3D%3D?line=10'>11</a> app = ApplicationBuilder().token(tg_token).build()
#      <a href='vscode-notebook-cell:/Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin%40gmail.com/My%20Drive/Colab%20Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb#Y122sZmlsZQ%3D%3D?line=12'>13</a> app.add_handler(CommandHandler("hello", hello))
# ---> <a href='vscode-notebook-cell:/Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin%40gmail.com/My%20Drive/Colab%20Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb#Y122sZmlsZQ%3D%3D?line=14'>15</a> app.run_polling()
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/site-packages/telegram/ext/_application.py:765, in Application.run_polling(self, poll_interval, timeout, bootstrap_retries, read_timeout, write_timeout, connect_timeout, pool_timeout, allowed_updates, drop_pending_updates, close_loop, stop_signals)
#     762 def error_callback(exc: TelegramError) -> None:
#     763     self.create_task(self.process_error(error=exc, update=None))
# --> 765 return self.__run(
#     766     updater_coroutine=self.updater.start_polling(
#     767         poll_interval=poll_interval,
#     768         timeout=timeout,
#     769         bootstrap_retries=bootstrap_retries,
#     770         read_timeout=read_timeout,
#     771         write_timeout=write_timeout,
#     772         connect_timeout=connect_timeout,
#     773         pool_timeout=pool_timeout,
#     774         allowed_updates=allowed_updates,
#     775         drop_pending_updates=drop_pending_updates,
#     776         error_callback=error_callback,  # if there is an error in fetching updates
#     777     ),
#     778     close_loop=close_loop,
#     779     stop_signals=stop_signals,
#     780 )
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/site-packages/telegram/ext/_application.py:973, in Application.__run(self, updater_coroutine, stop_signals, close_loop)
#     971 finally:
#     972     if close_loop:
# --> 973         loop.close()
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/asyncio/unix_events.py:68, in _UnixSelectorEventLoop.close(self)
#      67 def close(self):
# ---> 68     super().close()
#      69     if not sys.is_finalizing():
#      70         for sig in list(self._signal_handlers):
#
# File ~/miniconda3/envs/ask_media/lib/python3.10/asyncio/selector_events.py:84, in BaseSelectorEventLoop.close(self)
#      82 def close(self):
#      83     if self.is_running():
# ---> 84         raise RuntimeError("Cannot close a running event loop")
#      85     if self.is_closed():
#      86         return
#
# RuntimeError: Cannot close a running event loop

# %%
from telegram.ext import Updater, CommandHandler

# %%
def do_analysis(input):
    
    return f"result = {input}"

# %%
updater = Updater(token=tg_token, use_context=True) 

def start(update, context):
    update.message.reply_text("Hi! I'm your analysis bot.")

def analyze(update, context):
    input = context.args[0] 
    result = do_analysis(input)
    update.message.reply_text(result)

updater.dispatcher.add_handler(CommandHandler('start', start))
updater.dispatcher.add_handler(CommandHandler('analyze', analyze))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin@gmail.com/My Drive/Colab Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin%40gmail.com/My%20Drive/Colab%20Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb#Y124sZmlsZQ%3D%3D?line=0'>1</a> updater = Updater(token=tg_token, use_context=True)
#       <a href='vscode-notebook-cell:/Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin%40gmail.com/My%20Drive/Colab%20Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb#Y124sZmlsZQ%3D%3D?line=2'>3</a> def start(update, context):
#       <a href='vscode-notebook-cell:/Users/alexbadin/Library/CloudStorage/GoogleDrive-alex.badin%40gmail.com/My%20Drive/Colab%20Notebooks/Narratives/notebooks/ChatBot_ask_media_clean.ipynb#Y124sZmlsZQ%3D%3D?line=3'>4</a>     update.message.reply_text("Hi! I'm your analysis bot.")
#
# TypeError: Updater.__init__() got an unexpected keyword argument 'token'

# %%
updater.start_polling()
